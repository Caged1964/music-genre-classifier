# %% [markdown]
# IMPORTING LIBRARIES

# %%
import os
import h5py
import librosa
import itertools
from copy import copy
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Add
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import PReLU
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
# For reproducibility purposes
np.random.seed(42)

# %% [markdown]
# **Read the data**
# <!-- Helper functions to assist the process to read songs, split then and return an array of spectrograms/melspectrograms -->

# %%
# Method to split a song into multiple songs using overlapping windows

def splitsongs(X, y, window = 0.05, overlap = 0.5):
    # Empty lists to hold our results
    temp_X = []
    temp_y = []

    # Get the input song array size
    xshape = X.shape[0]
    chunk = int(xshape*window)
    offset = int(chunk*(1.-overlap))
    
    # Split the song and create new ones on windows
    spsong = [X[i:i+chunk] for i in range(0, xshape - chunk + offset, offset)]
    for s in spsong:
        if s.shape[0] != chunk:
            continue

        temp_X.append(s)
        temp_y.append(y)

    return np.array(temp_X), np.array(temp_y)

# %%
# Method to convert a list of songs to a np array of melspectrograms
def to_melspectrogram(songs, n_fft=1024, hop_length=256):
    # Transformation function
    melspec = lambda x: librosa.feature.melspectrogram(y=x, n_fft=n_fft,
        hop_length=hop_length, n_mels=128)[:,:,np.newaxis]

    # map transformation of input songs to melspectrogram using log-scale
    tsongs = map(melspec, songs)
    # np.array([librosa.power_to_db(s, ref=np.max) for s in list(tsongs)])
    return np.array(list(tsongs))

# %%
def split_convert(X, y):
    arr_specs, arr_genres = [], []
    
    # Convert to spectrograms and split into small windows
    for fn, genre in zip(X, y):
        signal, sr = librosa.load(fn)
        signal = signal[:song_samples]

        # Convert to dataset of spectograms/melspectograms
        signals, y = splitsongs(signal, genre)

        # Convert to "spec" representation
        specs = to_melspectrogram(signals)

        # Save files
        arr_genres.extend(y)
        arr_specs.extend(specs)
    
    return np.array(arr_specs), to_categorical(arr_genres)

# %%
def read_data(src_dir, genres, song_samples):    
    # Empty array of dicts with the processed features from all files
    arr_fn = []
    arr_genres = []

    # Get file list from the folders
    for x,_ in genres.items():
        folder = src_dir + x
        for root, subdirs, files in os.walk(folder):
            for file in files:
                file_name = folder + "/" + file

                # Save the file name and the genre
                arr_fn.append(file_name)
                arr_genres.append(genres[x])
    
    # Split into train and test
    X_train, X_test, y_train, y_test = train_test_split(
        arr_fn, arr_genres, test_size=0.3, random_state=42, stratify=arr_genres
    )
    
    # Split into small segments and convert to spectrogram
    X_train, y_train = split_convert(X_train, y_train)
    X_test, y_test = split_convert(X_test, y_test)

    return X_train, X_test, y_train, y_test

# %%
# Parameters
gtzan_dir = 'E:/archive/Data/genres_original/'
song_samples = 660000
genres = {'metal': 0, 'disco': 1, 'classical': 2, 'hiphop': 3, 'jazz': 4, 
          'country': 5, 'pop': 6, 'blues': 7, 'reggae': 8, 'rock': 9}

# Read the data
X_train, X_test, y_train, y_test = read_data(gtzan_dir, genres, song_samples)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (27300, 128, 129, 1) (11700, 128, 129, 1) (27300, 10) (11700, 10)

# %%
# Histogram for train and test 
values, count = np.unique(np.argmax(y_train, axis=1), return_counts=True)
plt.bar(values, count)

values, count = np.unique(np.argmax(y_test, axis=1), return_counts=True)
plt.bar(values, count)
plt.show()

# %% [markdown]
# **GTZAN Melspectrogram Generator**

# %%
from tensorflow.keras.utils import Sequence

class GTZANGenerator(Sequence):
    def __init__(self, X, y, batch_size=64, is_test = False):
        self.X = X
        self.y = y
        self.batch_size = batch_size
        self.is_test = is_test
    
    def __len__(self):
        return int(np.ceil(len(self.X)/self.batch_size))
    
    def __getitem__(self, index):
        # Get batch indexes
        signals = self.X[index*self.batch_size:(index+1)*self.batch_size]

        # Apply data augmentation
        if not self.is_test:
            signals = self.__augment(signals)
        return signals, self.y[index*self.batch_size:(index+1)*self.batch_size]
    
    def __augment(self, signals, hor_flip = 0.5, random_cutout = 0.5):
        spectrograms =  []
        for s in signals:
            signal = copy(s)
            
            # Perform horizontal flip
            if np.random.rand() < hor_flip:
                signal = np.flip(signal, 1)

            # Perform random cutoout of some frequency/time
            if np.random.rand() < random_cutout:
                lines = np.random.randint(signal.shape[0], size=3)
                cols = np.random.randint(signal.shape[0], size=4)
                signal[lines, :, :] = -80 # dB
                signal[:, cols, :] = -80 # dB

            spectrograms.append(signal)
        return np.array(spectrograms)
    
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.X))
        np.random.shuffle(self.indexes)
        return None

# %% [markdown]
# **Custom CNN (Melspectrogram version)**

# %%
def conv_block(x, n_filters, pool_size=(2, 2)):
    x = Conv2D(n_filters, (3, 3), strides=(1, 1), padding='same')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=pool_size, strides=pool_size)(x)
    x = Dropout(0.25)(x)
    return x

# %%
# Model Definition
def create_model(input_shape, num_genres):
    inpt = Input(shape=input_shape)
    x = conv_block(inpt, 16)
    x = conv_block(x, 32)
    x = conv_block(x, 64)
    x = conv_block(x, 128)
    x = conv_block(x, 256)
    
    # Global Pooling and MLP
    x = Flatten()(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu', 
              kernel_regularizer=tf.keras.regularizers.l2(0.02))(x)
    x = Dropout(0.25)(x)
    predictions = Dense(num_genres, 
                        activation='softmax', 
                        kernel_regularizer=tf.keras.regularizers.l2(0.02))(x)
    
    model = Model(inputs=inpt, outputs=predictions)
    return model

# %%
model = create_model(X_train[0].shape, len(genres))

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 129, 1)]     0
#
#  conv2d (Conv2D)             (None, 128, 129, 16)      160
#
#  activation (Activation)     (None, 128, 129, 16)      0
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)        0
#  D)
#
#  dropout (Dropout)           (None, 64, 64, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  activation_1 (Activation)   (None, 64, 64, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  activation_2 (Activation)   (None, 32, 32, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       73856
#
#  activation_3 (Activation)   (None, 16, 16, 128)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2495114 (9.52 MB)
# Trainable params: 2495114 (9.52 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Loss function**

# %%
model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
reduceLROnPlat = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.95,
    patience=3,
    verbose=1,
    mode='min',
    min_delta=0.0001,
    cooldown=2,
    min_lr=1e-5
)

# %%
# Generators
batch_size = 128
train_generator = GTZANGenerator(X_train, y_train)
steps_per_epoch = np.ceil(len(X_train)/batch_size)

validation_generator = GTZANGenerator(X_test, y_test)
val_steps = np.ceil(len(X_test)/batch_size)

# %%
hist = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=validation_generator,
    validation_steps=val_steps,
    epochs=150,
    verbose=1,
    callbacks=[reduceLROnPlat])
# Out:
# Epoch 1/150
# 214/214 [==============================] - 681s 3s/step - loss: 12.8227 - accuracy: 0.0932 - val_loss: 6.6326 - val_accuracy: 0.1472 - lr: 0.0010
# Epoch 2/150
# 214/214 [==============================] - 419s 2s/step - loss: 4.9163 - accuracy: 0.1564 - val_loss: 3.7682 - val_accuracy: 0.2172 - lr: 0.0010
# Epoch 3/150
# 214/214 [==============================] - 420s 2s/step - loss: 3.2580 - accuracy: 0.1632 - val_loss: 2.9142 - val_accuracy: 0.1649 - lr: 0.0010
# Epoch 4/150
# 214/214 [==============================] - 407s 2s/step - loss: 2.6737 - accuracy: 0.1829 - val_loss: 2.4687 - val_accuracy: 0.2483 - lr: 0.0010
# Epoch 5/150
# 214/214 [==============================] - 412s 2s/step - loss: 2.4467 - accuracy: 0.1831 - val_loss: 2.3022 - val_accuracy: 0.2255 - lr: 0.0010
# Epoch 6/150
# 214/214 [==============================] - 452s 2s/step - loss: 2.3201 - accuracy: 0.1849 - val_loss: 2.2342 - val_accuracy: 0.2485 - lr: 0.0010
# Epoch 7/150
# 214/214 [==============================] - 419s 2s/step - loss: 2.2509 - accuracy: 0.1955 - val_loss: 2.2201 - val_accuracy: 0.2021 - lr: 0.0010
# Epoch 8/150
# 214/214 [==============================] - 411s 2s/step - loss: 2.1704 - accuracy: 0.2095 - val_loss: 2.0819 - val_accuracy: 0.2643 - lr: 0.0010
# Epoch 9/150
# 214/214 [==============================] - 401s 2s/step - loss: 2.1569 - accuracy: 0.2136 - val_loss: 2.0412 - val_accuracy: 0.2553 - lr: 0.0010
# Epoch 10/150
# 214/214 [==============================] - 418s 2s/step - loss: 2.0907 - accuracy: 0.2369 - val_loss: 2.1175 - val_accuracy: 0.2430 - lr: 0.0010
# Epoch 11/150
# 214/214 [==============================] - 373s 2s/step - loss: 2.0872 - accuracy: 0.2297 - val_loss: 2.0164 - val_accuracy: 0.2609 - lr: 0.0010
# Epoch 12/150
# 214/214 [==============================] - 404s 2s/step - loss: 2.0930 - accuracy: 0.2466 - val_loss: 1.9952 - val_accuracy: 0.2459 - lr: 0.0010
# Epoch 13/150
# 214/214 [==============================] - 419s 2s/step - loss: 2.0672 - accuracy: 0.2631 - val_loss: 1.9743 - val_accuracy: 0.2300 - lr: 0.0010
# Epoch 14/150
# 214/214 [==============================] - 381s 2s/step - loss: 2.0692 - accuracy: 0.2429 - val_loss: 1.9845 - val_accuracy: 0.2965 - lr: 0.0010
# Epoch 15/150
# 214/214 [==============================] - 377s 2s/step - loss: 2.0236 - accuracy: 0.2755 - val_loss: 1.9355 - val_accuracy: 0.2486 - lr: 0.0010
# Epoch 16/150
# 214/214 [==============================] - 372s 2s/step - loss: 1.9782 - accuracy: 0.2785 - val_loss: 1.8920 - val_accuracy: 0.3047 - lr: 0.0010
# Epoch 17/150
# 214/214 [==============================] - 398s 2s/step - loss: 1.9650 - accuracy: 0.2848 - val_loss: 1.9140 - val_accuracy: 0.3105 - lr: 0.0010
# Epoch 18/150
# 214/214 [==============================] - 388s 2s/step - loss: 1.9729 - accuracy: 0.2940 - val_loss: 1.8314 - val_accuracy: 0.3424 - lr: 0.0010
# Epoch 19/150
# 214/214 [==============================] - 372s 2s/step - loss: 1.9760 - accuracy: 0.3011 - val_loss: 1.9266 - val_accuracy: 0.3081 - lr: 0.0010
# Epoch 20/150
# 214/214 [==============================] - 392s 2s/step - loss: 1.9341 - accuracy: 0.3182 - val_loss: 1.8322 - val_accuracy: 0.3225 - lr: 0.0010
# Epoch 21/150
# 214/214 [==============================] - 404s 2s/step - loss: 1.9309 - accuracy: 0.3147 - val_loss: 1.7963 - val_accuracy: 0.3796 - lr: 0.0010
# Epoch 22/150
# 214/214 [==============================] - 389s 2s/step - loss: 1.9111 - accuracy: 0.3274 - val_loss: 1.7787 - val_accuracy: 0.3529 - lr: 0.0010
# Epoch 23/150
# 214/214 [==============================] - 377s 2s/step - loss: 1.9165 - accuracy: 0.3059 - val_loss: 1.9543 - val_accuracy: 0.2863 - lr: 0.0010
# Epoch 24/150
# 214/214 [==============================] - 387s 2s/step - loss: 1.8939 - accuracy: 0.3278 - val_loss: 1.7992 - val_accuracy: 0.3150 - lr: 0.0010
# Epoch 25/150
# 214/214 [==============================] - ETA: 0s - loss: 1.9267 - accuracy: 0.2888
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0009500000451225787.
# 214/214 [==============================] - 388s 2s/step - loss: 1.9267 - accuracy: 0.2888 - val_loss: 1.8372 - val_accuracy: 0.3477 - lr: 0.0010
# Epoch 26/150
# 214/214 [==============================] - 407s 2s/step - loss: 1.8629 - accuracy: 0.3356 - val_loss: 1.7885 - val_accuracy: 0.3595 - lr: 9.5000e-04
# Epoch 27/150
# 214/214 [==============================] - 433s 2s/step - loss: 1.8249 - accuracy: 0.3387 - val_loss: 1.6855 - val_accuracy: 0.4258 - lr: 9.5000e-04
# Epoch 28/150
# 214/214 [==============================] - 391s 2s/step - loss: 1.8403 - accuracy: 0.3465 - val_loss: 1.7958 - val_accuracy: 0.3580 - lr: 9.5000e-04
# Epoch 29/150
# 214/214 [==============================] - 400s 2s/step - loss: 1.8494 - accuracy: 0.3443 - val_loss: 1.7047 - val_accuracy: 0.3944 - lr: 9.5000e-04
# Epoch 30/150
# 214/214 [==============================] - ETA: 0s - loss: 1.7896 - accuracy: 0.3919
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0009025000152178108.
# 214/214 [==============================] - 397s 2s/step - loss: 1.7896 - accuracy: 0.3919 - val_loss: 1.7564 - val_accuracy: 0.3964 - lr: 9.5000e-04
# Epoch 31/150
# 214/214 [==============================] - 368s 2s/step - loss: 1.7657 - accuracy: 0.4115 - val_loss: 1.6412 - val_accuracy: 0.4344 - lr: 9.0250e-04
# Epoch 32/150
# 214/214 [==============================] - 378s 2s/step - loss: 1.7356 - accuracy: 0.3997 - val_loss: 1.5558 - val_accuracy: 0.4917 - lr: 9.0250e-04
# Epoch 33/150
# 214/214 [==============================] - 377s 2s/step - loss: 1.7086 - accuracy: 0.4249 - val_loss: 1.5941 - val_accuracy: 0.4713 - lr: 9.0250e-04
# Epoch 34/150
# 214/214 [==============================] - 390s 2s/step - loss: 1.6890 - accuracy: 0.4221 - val_loss: 1.6200 - val_accuracy: 0.4536 - lr: 9.0250e-04
# Epoch 35/150
# 214/214 [==============================] - ETA: 0s - loss: 1.6578 - accuracy: 0.4390
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0008573750033974647.
# 214/214 [==============================] - 375s 2s/step - loss: 1.6578 - accuracy: 0.4390 - val_loss: 1.6613 - val_accuracy: 0.4112 - lr: 9.0250e-04
# Epoch 36/150
# 214/214 [==============================] - 380s 2s/step - loss: 1.6807 - accuracy: 0.4214 - val_loss: 1.5916 - val_accuracy: 0.4541 - lr: 8.5737e-04
# Epoch 37/150
# 214/214 [==============================] - 367s 2s/step - loss: 1.6178 - accuracy: 0.4538 - val_loss: 1.6385 - val_accuracy: 0.4226 - lr: 8.5737e-04
# Epoch 38/150
# 214/214 [==============================] - 402s 2s/step - loss: 1.6177 - accuracy: 0.4566 - val_loss: 1.5340 - val_accuracy: 0.4732 - lr: 8.5737e-04
# Epoch 39/150
# 214/214 [==============================] - 378s 2s/step - loss: 1.5885 - accuracy: 0.4544 - val_loss: 1.4935 - val_accuracy: 0.5122 - lr: 8.5737e-04
# Epoch 40/150
# 214/214 [==============================] - 376s 2s/step - loss: 1.6055 - accuracy: 0.4582 - val_loss: 1.4839 - val_accuracy: 0.5197 - lr: 8.5737e-04
# Epoch 41/150
# 214/214 [==============================] - 384s 2s/step - loss: 1.6015 - accuracy: 0.4653 - val_loss: 1.5329 - val_accuracy: 0.4794 - lr: 8.5737e-04
# Epoch 42/150
# 214/214 [==============================] - 381s 2s/step - loss: 1.5806 - accuracy: 0.4606 - val_loss: 1.4614 - val_accuracy: 0.5099 - lr: 8.5737e-04
# Epoch 43/150
# 214/214 [==============================] - 379s 2s/step - loss: 1.4979 - accuracy: 0.5078 - val_loss: 1.4416 - val_accuracy: 0.5165 - lr: 8.5737e-04
# Epoch 44/150
# 214/214 [==============================] - 375s 2s/step - loss: 1.5588 - accuracy: 0.4732 - val_loss: 1.3819 - val_accuracy: 0.5516 - lr: 8.5737e-04
# Epoch 45/150
# 214/214 [==============================] - 400s 2s/step - loss: 1.5189 - accuracy: 0.5239 - val_loss: 1.5801 - val_accuracy: 0.4518 - lr: 8.5737e-04
# Epoch 46/150
# 214/214 [==============================] - 382s 2s/step - loss: 1.5639 - accuracy: 0.4944 - val_loss: 1.4155 - val_accuracy: 0.5452 - lr: 8.5737e-04
# Epoch 47/150
# 214/214 [==============================] - ETA: 0s - loss: 1.4908 - accuracy: 0.5129
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0008145062311086804.
# 214/214 [==============================] - 406s 2s/step - loss: 1.4908 - accuracy: 0.5129 - val_loss: 1.4583 - val_accuracy: 0.5312 - lr: 8.5737e-04
# Epoch 48/150
# 214/214 [==============================] - 389s 2s/step - loss: 1.5457 - accuracy: 0.4973 - val_loss: 1.3689 - val_accuracy: 0.5700 - lr: 8.1451e-04
# Epoch 49/150
# 214/214 [==============================] - 389s 2s/step - loss: 1.4647 - accuracy: 0.5143 - val_loss: 1.4374 - val_accuracy: 0.5316 - lr: 8.1451e-04
# Epoch 50/150
# 214/214 [==============================] - 421s 2s/step - loss: 1.4930 - accuracy: 0.5209 - val_loss: 1.4204 - val_accuracy: 0.5540 - lr: 8.1451e-04
# Epoch 51/150
# 214/214 [==============================] - 391s 2s/step - loss: 1.5031 - accuracy: 0.5314 - val_loss: 1.3186 - val_accuracy: 0.5795 - lr: 8.1451e-04
# Epoch 52/150
# 214/214 [==============================] - 414s 2s/step - loss: 1.3558 - accuracy: 0.5663 - val_loss: 1.3183 - val_accuracy: 0.5859 - lr: 8.1451e-04
# Epoch 53/150
# 214/214 [==============================] - 380s 2s/step - loss: 1.4570 - accuracy: 0.5341 - val_loss: 1.3142 - val_accuracy: 0.5968 - lr: 8.1451e-04
# Epoch 54/150
# 214/214 [==============================] - 424s 2s/step - loss: 1.4093 - accuracy: 0.5596 - val_loss: 1.3650 - val_accuracy: 0.5637 - lr: 8.1451e-04
# Epoch 55/150
# 214/214 [==============================] - 404s 2s/step - loss: 1.4287 - accuracy: 0.5462 - val_loss: 1.3838 - val_accuracy: 0.5428 - lr: 8.1451e-04
# Epoch 56/150
# 214/214 [==============================] - ETA: 0s - loss: 1.4440 - accuracy: 0.5343
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.0007737808919046074.
# 214/214 [==============================] - 426s 2s/step - loss: 1.4440 - accuracy: 0.5343 - val_loss: 1.3175 - val_accuracy: 0.6070 - lr: 8.1451e-04
# Epoch 57/150
# 214/214 [==============================] - 429s 2s/step - loss: 1.3536 - accuracy: 0.5778 - val_loss: 1.2529 - val_accuracy: 0.6080 - lr: 7.7378e-04
# Epoch 58/150
# 214/214 [==============================] - 425s 2s/step - loss: 1.3507 - accuracy: 0.5699 - val_loss: 1.3083 - val_accuracy: 0.5875 - lr: 7.7378e-04
# Epoch 59/150
# 214/214 [==============================] - 385s 2s/step - loss: 1.3572 - accuracy: 0.5744 - val_loss: 1.3111 - val_accuracy: 0.5994 - lr: 7.7378e-04
# Epoch 60/150
# 214/214 [==============================] - ETA: 0s - loss: 1.3576 - accuracy: 0.5762
# Epoch 60: ReduceLROnPlateau reducing learning rate to 0.000735091819660738.
# 214/214 [==============================] - 388s 2s/step - loss: 1.3576 - accuracy: 0.5762 - val_loss: 1.2629 - val_accuracy: 0.6026 - lr: 7.7378e-04
# Epoch 61/150
# 214/214 [==============================] - 428s 2s/step - loss: 1.3672 - accuracy: 0.5686 - val_loss: 1.2829 - val_accuracy: 0.5871 - lr: 7.3509e-04
# Epoch 62/150
# 214/214 [==============================] - 380s 2s/step - loss: 1.3529 - accuracy: 0.5748 - val_loss: 1.2374 - val_accuracy: 0.6082 - lr: 7.3509e-04
# Epoch 63/150
# 214/214 [==============================] - 390s 2s/step - loss: 1.3226 - accuracy: 0.5832 - val_loss: 1.2945 - val_accuracy: 0.5824 - lr: 7.3509e-04
# Epoch 64/150
# 214/214 [==============================] - 393s 2s/step - loss: 1.3348 - accuracy: 0.5779 - val_loss: 1.2438 - val_accuracy: 0.6148 - lr: 7.3509e-04
# Epoch 65/150
# 214/214 [==============================] - ETA: 0s - loss: 1.3216 - accuracy: 0.5860
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0006983372120885178.
# 214/214 [==============================] - 425s 2s/step - loss: 1.3216 - accuracy: 0.5860 - val_loss: 1.3190 - val_accuracy: 0.6146 - lr: 7.3509e-04
# Epoch 66/150
# 214/214 [==============================] - 397s 2s/step - loss: 1.3159 - accuracy: 0.5921 - val_loss: 1.1778 - val_accuracy: 0.6376 - lr: 6.9834e-04
# Epoch 67/150
# 214/214 [==============================] - 389s 2s/step - loss: 1.3198 - accuracy: 0.5769 - val_loss: 1.2533 - val_accuracy: 0.5885 - lr: 6.9834e-04
# Epoch 68/150
# 214/214 [==============================] - 407s 2s/step - loss: 1.2595 - accuracy: 0.6090 - val_loss: 1.3176 - val_accuracy: 0.5888 - lr: 6.9834e-04
# Epoch 69/150
# 214/214 [==============================] - ETA: 0s - loss: 1.2679 - accuracy: 0.6013
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.0006634203542489559.
# 214/214 [==============================] - 375s 2s/step - loss: 1.2679 - accuracy: 0.6013 - val_loss: 1.2254 - val_accuracy: 0.6187 - lr: 6.9834e-04
# Epoch 70/150
# 214/214 [==============================] - 387s 2s/step - loss: 1.3083 - accuracy: 0.5962 - val_loss: 1.1877 - val_accuracy: 0.6415 - lr: 6.6342e-04
# Epoch 71/150
# 214/214 [==============================] - 383s 2s/step - loss: 1.2914 - accuracy: 0.6065 - val_loss: 1.1686 - val_accuracy: 0.6450 - lr: 6.6342e-04
# Epoch 72/150
# 214/214 [==============================] - 372s 2s/step - loss: 1.2029 - accuracy: 0.6232 - val_loss: 1.2283 - val_accuracy: 0.6236 - lr: 6.6342e-04
# Epoch 73/150
# 214/214 [==============================] - 382s 2s/step - loss: 1.2306 - accuracy: 0.6188 - val_loss: 1.1670 - val_accuracy: 0.6447 - lr: 6.6342e-04
# Epoch 74/150
# 214/214 [==============================] - 374s 2s/step - loss: 1.2503 - accuracy: 0.6189 - val_loss: 1.2573 - val_accuracy: 0.6155 - lr: 6.6342e-04
# Epoch 75/150
# 214/214 [==============================] - 416s 2s/step - loss: 1.2483 - accuracy: 0.6097 - val_loss: 1.1885 - val_accuracy: 0.6445 - lr: 6.6342e-04
# Epoch 76/150
# 214/214 [==============================] - ETA: 0s - loss: 1.2720 - accuracy: 0.6009
# Epoch 76: ReduceLROnPlateau reducing learning rate to 0.0006302493420662358.
# 214/214 [==============================] - 401s 2s/step - loss: 1.2720 - accuracy: 0.6009 - val_loss: 1.2585 - val_accuracy: 0.6011 - lr: 6.6342e-04
# Epoch 77/150
# 214/214 [==============================] - 385s 2s/step - loss: 1.2410 - accuracy: 0.6260 - val_loss: 1.2412 - val_accuracy: 0.6347 - lr: 6.3025e-04
# Epoch 78/150
# 214/214 [==============================] - 388s 2s/step - loss: 1.1876 - accuracy: 0.6392 - val_loss: 1.1571 - val_accuracy: 0.6369 - lr: 6.3025e-04
# Epoch 79/150
# 214/214 [==============================] - 391s 2s/step - loss: 1.2363 - accuracy: 0.6169 - val_loss: 1.2074 - val_accuracy: 0.6459 - lr: 6.3025e-04
# Epoch 80/150
# 214/214 [==============================] - 460s 2s/step - loss: 1.2119 - accuracy: 0.6307 - val_loss: 1.1193 - val_accuracy: 0.6709 - lr: 6.3025e-04
# Epoch 81/150
# 214/214 [==============================] - 397s 2s/step - loss: 1.2024 - accuracy: 0.6264 - val_loss: 1.1512 - val_accuracy: 0.6539 - lr: 6.3025e-04
# Epoch 82/150
# 214/214 [==============================] - 431s 2s/step - loss: 1.2034 - accuracy: 0.6312 - val_loss: 1.2150 - val_accuracy: 0.6272 - lr: 6.3025e-04
# Epoch 83/150
# 214/214 [==============================] - ETA: 0s - loss: 1.2135 - accuracy: 0.6295
# Epoch 83: ReduceLROnPlateau reducing learning rate to 0.0005987368611386045.
# 214/214 [==============================] - 424s 2s/step - loss: 1.2135 - accuracy: 0.6295 - val_loss: 1.1879 - val_accuracy: 0.6393 - lr: 6.3025e-04
# Epoch 84/150
# 214/214 [==============================] - 405s 2s/step - loss: 1.1569 - accuracy: 0.6484 - val_loss: 1.1358 - val_accuracy: 0.6602 - lr: 5.9874e-04
# Epoch 85/150
# 214/214 [==============================] - 386s 2s/step - loss: 1.1175 - accuracy: 0.6569 - val_loss: 1.1625 - val_accuracy: 0.6357 - lr: 5.9874e-04
# Epoch 86/150
# 214/214 [==============================] - 465s 2s/step - loss: 1.1515 - accuracy: 0.6575 - val_loss: 1.1009 - val_accuracy: 0.6685 - lr: 5.9874e-04
# Epoch 87/150
# 214/214 [==============================] - 409s 2s/step - loss: 1.1872 - accuracy: 0.6328 - val_loss: 1.1233 - val_accuracy: 0.6624 - lr: 5.9874e-04
# Epoch 88/150
# 214/214 [==============================] - 393s 2s/step - loss: 1.1299 - accuracy: 0.6508 - val_loss: 1.1449 - val_accuracy: 0.6349 - lr: 5.9874e-04
# Epoch 89/150
# 214/214 [==============================] - ETA: 0s - loss: 1.1736 - accuracy: 0.6373
# Epoch 89: ReduceLROnPlateau reducing learning rate to 0.0005688000208465382.
# 214/214 [==============================] - 422s 2s/step - loss: 1.1736 - accuracy: 0.6373 - val_loss: 1.1589 - val_accuracy: 0.6501 - lr: 5.9874e-04
# Epoch 90/150
# 214/214 [==============================] - 395s 2s/step - loss: 1.1054 - accuracy: 0.6630 - val_loss: 1.1227 - val_accuracy: 0.6603 - lr: 5.6880e-04
# Epoch 91/150
# 214/214 [==============================] - 391s 2s/step - loss: 1.1301 - accuracy: 0.6512 - val_loss: 1.1607 - val_accuracy: 0.6500 - lr: 5.6880e-04
# Epoch 92/150
# 214/214 [==============================] - 420s 2s/step - loss: 1.1253 - accuracy: 0.6582 - val_loss: 1.0850 - val_accuracy: 0.6668 - lr: 5.6880e-04
# Epoch 93/150
# 214/214 [==============================] - 389s 2s/step - loss: 1.1541 - accuracy: 0.6602 - val_loss: 1.0715 - val_accuracy: 0.6681 - lr: 5.6880e-04
# Epoch 94/150
# 214/214 [==============================] - 402s 2s/step - loss: 1.0952 - accuracy: 0.6667 - val_loss: 1.0999 - val_accuracy: 0.6858 - lr: 5.6880e-04
# Epoch 95/150
# 214/214 [==============================] - 437s 2s/step - loss: 1.0779 - accuracy: 0.6703 - val_loss: 1.1519 - val_accuracy: 0.6503 - lr: 5.6880e-04
# Epoch 96/150
# 214/214 [==============================] - ETA: 0s - loss: 1.1504 - accuracy: 0.6554
# Epoch 96: ReduceLROnPlateau reducing learning rate to 0.0005403600225690752.
# 214/214 [==============================] - 458s 2s/step - loss: 1.1504 - accuracy: 0.6554 - val_loss: 1.0888 - val_accuracy: 0.6775 - lr: 5.6880e-04
# Epoch 97/150
# 214/214 [==============================] - 416s 2s/step - loss: 1.0636 - accuracy: 0.6755 - val_loss: 1.1529 - val_accuracy: 0.6537 - lr: 5.4036e-04
# Epoch 98/150
# 214/214 [==============================] - 430s 2s/step - loss: 1.1264 - accuracy: 0.6622 - val_loss: 1.0992 - val_accuracy: 0.6663 - lr: 5.4036e-04
# Epoch 99/150
# 214/214 [==============================] - 397s 2s/step - loss: 1.0728 - accuracy: 0.6801 - val_loss: 1.0694 - val_accuracy: 0.6868 - lr: 5.4036e-04
# Epoch 100/150
# 214/214 [==============================] - 474s 2s/step - loss: 1.0707 - accuracy: 0.6745 - val_loss: 1.0627 - val_accuracy: 0.6788 - lr: 5.4036e-04
# Epoch 101/150
# 214/214 [==============================] - 403s 2s/step - loss: 1.0763 - accuracy: 0.6755 - val_loss: 1.0425 - val_accuracy: 0.6872 - lr: 5.4036e-04
# Epoch 102/150
# 214/214 [==============================] - 398s 2s/step - loss: 1.1166 - accuracy: 0.6601 - val_loss: 1.0759 - val_accuracy: 0.6855 - lr: 5.4036e-04
# Epoch 103/150
# 214/214 [==============================] - 397s 2s/step - loss: 1.0619 - accuracy: 0.6826 - val_loss: 1.0457 - val_accuracy: 0.6890 - lr: 5.4036e-04
# Epoch 104/150
# 214/214 [==============================] - ETA: 0s - loss: 1.0478 - accuracy: 0.6823
# Epoch 104: ReduceLROnPlateau reducing learning rate to 0.0005133419937919825.
# 214/214 [==============================] - 420s 2s/step - loss: 1.0478 - accuracy: 0.6823 - val_loss: 1.0684 - val_accuracy: 0.6824 - lr: 5.4036e-04
# Epoch 105/150
# 214/214 [==============================] - 407s 2s/step - loss: 1.0906 - accuracy: 0.6736 - val_loss: 1.0841 - val_accuracy: 0.6729 - lr: 5.1334e-04
# Epoch 106/150
# 214/214 [==============================] - 395s 2s/step - loss: 1.0780 - accuracy: 0.6821 - val_loss: 1.0495 - val_accuracy: 0.6890 - lr: 5.1334e-04
# Epoch 107/150
# 214/214 [==============================] - 421s 2s/step - loss: 1.0802 - accuracy: 0.6687 - val_loss: 1.1330 - val_accuracy: 0.6396 - lr: 5.1334e-04
# Epoch 108/150
# 214/214 [==============================] - ETA: 0s - loss: 1.0548 - accuracy: 0.6880
# Epoch 108: ReduceLROnPlateau reducing learning rate to 0.0004876748775132.
# 214/214 [==============================] - 398s 2s/step - loss: 1.0548 - accuracy: 0.6880 - val_loss: 1.0748 - val_accuracy: 0.6807 - lr: 5.1334e-04
# Epoch 109/150
# 214/214 [==============================] - 404s 2s/step - loss: 1.0260 - accuracy: 0.6933 - val_loss: 1.1230 - val_accuracy: 0.6602 - lr: 4.8767e-04
# Epoch 110/150
# 214/214 [==============================] - 407s 2s/step - loss: 1.0192 - accuracy: 0.6907 - val_loss: 1.0670 - val_accuracy: 0.6817 - lr: 4.8767e-04
# Epoch 111/150
# 214/214 [==============================] - 386s 2s/step - loss: 1.0332 - accuracy: 0.6891 - val_loss: 1.0322 - val_accuracy: 0.6917 - lr: 4.8767e-04
# Epoch 112/150
# 214/214 [==============================] - 409s 2s/step - loss: 1.0502 - accuracy: 0.6790 - val_loss: 1.0645 - val_accuracy: 0.6771 - lr: 4.8767e-04
# Epoch 113/150
# 214/214 [==============================] - 386s 2s/step - loss: 1.0626 - accuracy: 0.6789 - val_loss: 1.0214 - val_accuracy: 0.7048 - lr: 4.8767e-04
# Epoch 114/150
# 214/214 [==============================] - 397s 2s/step - loss: 1.0216 - accuracy: 0.6849 - val_loss: 1.0566 - val_accuracy: 0.6933 - lr: 4.8767e-04
# Epoch 115/150
# 214/214 [==============================] - 402s 2s/step - loss: 0.9986 - accuracy: 0.6973 - val_loss: 1.0427 - val_accuracy: 0.6951 - lr: 4.8767e-04
# Epoch 116/150
# 214/214 [==============================] - ETA: 0s - loss: 1.0276 - accuracy: 0.6926
# Epoch 116: ReduceLROnPlateau reducing learning rate to 0.00046329112810781223.
# 214/214 [==============================] - 386s 2s/step - loss: 1.0276 - accuracy: 0.6926 - val_loss: 1.0474 - val_accuracy: 0.6960 - lr: 4.8767e-04
# Epoch 117/150
# 214/214 [==============================] - 393s 2s/step - loss: 0.9913 - accuracy: 0.7010 - val_loss: 1.0346 - val_accuracy: 0.7002 - lr: 4.6329e-04
# Epoch 118/150
# 214/214 [==============================] - 389s 2s/step - loss: 0.9958 - accuracy: 0.6971 - val_loss: 1.0152 - val_accuracy: 0.6957 - lr: 4.6329e-04
# Epoch 119/150
# 214/214 [==============================] - 391s 2s/step - loss: 1.0306 - accuracy: 0.6922 - val_loss: 1.0956 - val_accuracy: 0.6693 - lr: 4.6329e-04
# Epoch 120/150
# 214/214 [==============================] - 403s 2s/step - loss: 0.9423 - accuracy: 0.7198 - val_loss: 1.0228 - val_accuracy: 0.6931 - lr: 4.6329e-04
# Epoch 121/150
# 214/214 [==============================] - ETA: 0s - loss: 1.0155 - accuracy: 0.6918
# Epoch 121: ReduceLROnPlateau reducing learning rate to 0.00044012657308485355.
# 214/214 [==============================] - 410s 2s/step - loss: 1.0155 - accuracy: 0.6918 - val_loss: 1.0193 - val_accuracy: 0.7038 - lr: 4.6329e-04
# Epoch 122/150
# 214/214 [==============================] - 396s 2s/step - loss: 0.9703 - accuracy: 0.7139 - val_loss: 1.0884 - val_accuracy: 0.6765 - lr: 4.4013e-04
# Epoch 123/150
# 214/214 [==============================] - 411s 2s/step - loss: 0.9923 - accuracy: 0.6930 - val_loss: 1.0122 - val_accuracy: 0.6967 - lr: 4.4013e-04
# Epoch 124/150
# 214/214 [==============================] - 399s 2s/step - loss: 0.9619 - accuracy: 0.7077 - val_loss: 1.0208 - val_accuracy: 0.6948 - lr: 4.4013e-04
# Epoch 125/150
# 214/214 [==============================] - 389s 2s/step - loss: 0.9770 - accuracy: 0.7096 - val_loss: 1.0067 - val_accuracy: 0.7035 - lr: 4.4013e-04
# Epoch 126/150
# 214/214 [==============================] - 408s 2s/step - loss: 0.9693 - accuracy: 0.7078 - val_loss: 0.9771 - val_accuracy: 0.7131 - lr: 4.4013e-04
# Epoch 127/150
# 214/214 [==============================] - 394s 2s/step - loss: 0.9533 - accuracy: 0.7222 - val_loss: 1.0095 - val_accuracy: 0.7072 - lr: 4.4013e-04
# Epoch 128/150
# 214/214 [==============================] - 389s 2s/step - loss: 0.9345 - accuracy: 0.7188 - val_loss: 1.0719 - val_accuracy: 0.6831 - lr: 4.4013e-04
# Epoch 129/150
# 214/214 [==============================] - ETA: 0s - loss: 0.9837 - accuracy: 0.7071
# Epoch 129: ReduceLROnPlateau reducing learning rate to 0.00041812024719547477.
# 214/214 [==============================] - 390s 2s/step - loss: 0.9837 - accuracy: 0.7071 - val_loss: 1.0024 - val_accuracy: 0.7013 - lr: 4.4013e-04
# Epoch 130/150
# 214/214 [==============================] - 414s 2s/step - loss: 0.9698 - accuracy: 0.7114 - val_loss: 1.0329 - val_accuracy: 0.7013 - lr: 4.1812e-04
# Epoch 131/150
# 214/214 [==============================] - 396s 2s/step - loss: 0.9099 - accuracy: 0.7284 - val_loss: 1.0436 - val_accuracy: 0.6868 - lr: 4.1812e-04
# Epoch 132/150
# 214/214 [==============================] - 396s 2s/step - loss: 0.9272 - accuracy: 0.7206 - val_loss: 1.0220 - val_accuracy: 0.6926 - lr: 4.1812e-04
# Epoch 133/150
# 214/214 [==============================] - ETA: 0s - loss: 0.9217 - accuracy: 0.7229
# Epoch 133: ReduceLROnPlateau reducing learning rate to 0.00039721422654110934.
# 214/214 [==============================] - 392s 2s/step - loss: 0.9217 - accuracy: 0.7229 - val_loss: 1.0075 - val_accuracy: 0.7018 - lr: 4.1812e-04
# Epoch 134/150
# 214/214 [==============================] - 393s 2s/step - loss: 0.9215 - accuracy: 0.7270 - val_loss: 1.0162 - val_accuracy: 0.6970 - lr: 3.9721e-04
# Epoch 135/150
# 214/214 [==============================] - 388s 2s/step - loss: 0.9426 - accuracy: 0.7225 - val_loss: 0.9946 - val_accuracy: 0.7082 - lr: 3.9721e-04
# Epoch 136/150
# 214/214 [==============================] - 385s 2s/step - loss: 0.9136 - accuracy: 0.7296 - val_loss: 1.0055 - val_accuracy: 0.7125 - lr: 3.9721e-04
# Epoch 137/150
# 214/214 [==============================] - ETA: 0s - loss: 0.8918 - accuracy: 0.7338
# Epoch 137: ReduceLROnPlateau reducing learning rate to 0.00037735351797891776.
# 214/214 [==============================] - 389s 2s/step - loss: 0.8918 - accuracy: 0.7338 - val_loss: 0.9890 - val_accuracy: 0.7121 - lr: 3.9721e-04
# Epoch 138/150
# 214/214 [==============================] - 387s 2s/step - loss: 0.8880 - accuracy: 0.7365 - val_loss: 0.9776 - val_accuracy: 0.7033 - lr: 3.7735e-04
# Epoch 139/150
# 214/214 [==============================] - 405s 2s/step - loss: 0.9300 - accuracy: 0.7217 - val_loss: 0.9938 - val_accuracy: 0.6989 - lr: 3.7735e-04
# Epoch 140/150
# 214/214 [==============================] - 394s 2s/step - loss: 0.8910 - accuracy: 0.7371 - val_loss: 0.9675 - val_accuracy: 0.7148 - lr: 3.7735e-04
# Epoch 141/150
# 214/214 [==============================] - 394s 2s/step - loss: 0.9080 - accuracy: 0.7244 - val_loss: 1.0304 - val_accuracy: 0.6902 - lr: 3.7735e-04
# Epoch 142/150
# 214/214 [==============================] - 395s 2s/step - loss: 0.9584 - accuracy: 0.7068 - val_loss: 0.9454 - val_accuracy: 0.7131 - lr: 3.7735e-04
# Epoch 143/150
# 214/214 [==============================] - 387s 2s/step - loss: 0.9553 - accuracy: 0.7113 - val_loss: 0.9678 - val_accuracy: 0.7169 - lr: 3.7735e-04
# Epoch 144/150
# 214/214 [==============================] - 392s 2s/step - loss: 0.8958 - accuracy: 0.7321 - val_loss: 0.9877 - val_accuracy: 0.6974 - lr: 3.7735e-04
# Epoch 145/150
# 214/214 [==============================] - ETA: 0s - loss: 0.8791 - accuracy: 0.7430
# Epoch 145: ReduceLROnPlateau reducing learning rate to 0.00035848583793267607.
# 214/214 [==============================] - 389s 2s/step - loss: 0.8791 - accuracy: 0.7430 - val_loss: 1.0002 - val_accuracy: 0.6951 - lr: 3.7735e-04
# Epoch 146/150
# 214/214 [==============================] - 431s 2s/step - loss: 0.9290 - accuracy: 0.7210 - val_loss: 0.9642 - val_accuracy: 0.7176 - lr: 3.5849e-04
# Epoch 147/150
# 214/214 [==============================] - 471s 2s/step - loss: 0.8661 - accuracy: 0.7447 - val_loss: 0.9991 - val_accuracy: 0.6972 - lr: 3.5849e-04
# Epoch 148/150
# 214/214 [==============================] - 403s 2s/step - loss: 0.9134 - accuracy: 0.7280 - val_loss: 0.9908 - val_accuracy: 0.7193 - lr: 3.5849e-04
# Epoch 149/150
# 214/214 [==============================] - ETA: 0s - loss: 0.9109 - accuracy: 0.7261
# Epoch 149: ReduceLROnPlateau reducing learning rate to 0.00034056155709549785.
# 214/214 [==============================] - 418s 2s/step - loss: 0.9109 - accuracy: 0.7261 - val_loss: 0.9975 - val_accuracy: 0.7048 - lr: 3.5849e-04
# Epoch 150/150
# 214/214 [==============================] - 393s 2s/step - loss: 0.9124 - accuracy: 0.7161 - val_loss: 0.9487 - val_accuracy: 0.7232 - lr: 3.4056e-04

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print("val_loss = {:.3f} and val_acc = {:.3f}".format(score[0], score[1]))
# Out:
# val_loss = 0.940 and val_acc = 0.723

# %%
plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
plt.plot(hist.history['accuracy'], label='train')
plt.plot(hist.history['val_accuracy'], label='validation')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='validation')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
#http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
preds = np.argmax(model.predict(X_test), axis = 1)
y_orig = np.argmax(y_test, axis = 1)
cm = confusion_matrix(preds, y_orig)
# Out:
# 366/366 [==============================] - 115s 194ms/step

# %%
keys = OrderedDict(sorted(genres.items(), key=lambda t: t[1])).keys()

plt.figure(figsize=(10,10))
plot_confusion_matrix(cm, keys, normalize=True)
# Out:
# Normalized confusion matrix

# %% [markdown]
# **Majority Vote**

# %%
def majority_vote(scores):
    values, counts = np.unique(scores,return_counts=True)
    ind = np.argmax(counts)
    return values[ind]

# %%
preds = model.predict(X_test, batch_size=128, verbose=0)

# %%
# Each sound was divided into 39 segments in our custom function
scores_songs = np.split(np.argmax(preds, axis=1), 300)
scores_songs = [majority_vote(scores) for scores in scores_songs]

# %%
# Same analysis for split
label = np.split(np.argmax(y_test, axis=1), 300)
label = [majority_vote(l) for l in label]
from sklearn.metrics import accuracy_score

print("majority voting system (acc) = {:.3f}".format(accuracy_score(label, scores_songs)))
# Out:
# majority voting system (acc) = 0.817

# %%
model.save('C:/Users/Naman Jain/Desktop/Music Genre Classification/models/MyClassifier.h5')
# Out:
# c:\Users\Naman Jain\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
